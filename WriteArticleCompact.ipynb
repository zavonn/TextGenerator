# %%
from TextGenerate import *
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\zvnow\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# Using TensorFlow backend.

# %%
show_me()
# Out:
# The Most Frequently Used Words in the Titles assigned to Cluster 0 are:
#
# The Most Frequently Used Words in the Titles assigned to Cluster 1 are:
#
# The Most Frequently Used Words in the Titles assigned to Cluster 2 are:
#
# The Most Frequently Used Words in the Titles assigned to Cluster 3 are:
#
# The Most Frequently Used Words in the Titles assigned to Cluster 4 are:
#
# The Most Frequently Used Words in the Titles assigned to Cluster 5 are:
#
# The Most Frequently Used Words in the Titles assigned to Cluster 6 are:
#
# The Most Frequently Used Words in the Titles assigned to Cluster 7 are:
#
# The Most Frequently Used Words in the Titles assigned to Cluster 8 are:
#
# The Most Frequently Used Words in the Titles assigned to Cluster 9 are:

# %%
write_article(150)
# Out:
# Choose some keywords for your Article here: man arrested watch women about
#
# Your Article has been assigned Cluster #3
#
# The Most Frequently Used Words in the Titles assigned to Cluster 3 are:
#
# Vocab Size Loaded
#
# Vocabulary Loaded
#
# Vocabulary Inverse Dict Loaded
#
# The Size of the Vocabulary in the Cluster is 19015
#
# Loading LSTM Model...
# LSTM Model Loaded
#
# Type the first 6 words of your article here: who here can talk about what happened
#
# ...
